# %%
#set the pyspark environment variables
import os
os.environ['SPARK_HOME']= r"D:\spark"
os.environ['PYSPARK_DRIVER_PYTHON']='jupiter'
os.environ['PYSPARK_DRIVER_PYTHON_OPTS']='lab'
os.environ['PYSPARK_PYTHON']='python'

# %%
#import pyspark
from pyspark.sql import SparkSession

# %%
#create spark session
spark = SparkSession.builder\
     .appName("pyspark-get-started")\
     .getOrCreate()

# %%
#test the setup
data=[("Alice",25), ("Bob", 30),("Charlie",35)]
df=spark.createDataFrame(data,["Name", "Age"])
df.show()
# Out:
# +-------+---+
# |   Name|Age|
# +-------+---+
# |  Alice| 25|
# |    Bob| 30|
# |Charlie| 35|
# +-------+---+

# %%
import os
import zipfile

from pyspark.sql import SparkSession
from pyspark.sql.functions import col, lower, trim, collect_set

# %%
ZIP_FILES = [
faers_ascii_2024Q1.zipfaers_ascii_2024Q2.zipfaers_ascii_2024Q3.zipfaers_ascii_2024Q4.zipfaers_ascii_2025q1 (1).zipfaers_ascii_2025q2 (2).zipfaers_ascii_2025q3 (2).zip]

DRUG_LIST = [
    "Lamotrigine","Levetiracetam","Topiramate","Gabapentin","Pregabalin",
    "Oxcarbazepine","Zonisamide","Lacosamide","Clobazam","Phenytoin",
    "Carbamazepine","Phenobarbital","Valproic acid","Sodium valproate",
    "Ethosuximide","Levodopa + Carbidopa","Bromocriptine","Pramipexole",
    "Ropinirole","Rotigotine","Apomorphine","Selegiline","Rasagiline",
    "Safinamide","Entacapone","Tolcapone","Trihexyphenidyl","Benztropine",
    "Amantadine","Donepezil","Rivastigmine","Galantamine","Memantine",
    "Fingolimod","Natalizumab","Ocrelizumab","Baclofen","Modafinil",
    "Sumatriptan","Ibuprofen","Dihydroergotamine"
]

DRUG_LIST_LOWER = [d.lower().strip() for d in DRUG_LIST]

# %%
import tempfile
from functools import reduce
from pyspark.sql import DataFrame
from pyspark.sql import SparkSession

# Make sure Spark session is running
spark = SparkSession.builder.appName("FAERS Reader").getOrCreate()

def read_faers_tables_spark(table_keyword):
    dfs = []
    
    for zip_path in ZIP_FILES:
        if not os.path.exists(zip_path):
            continue
        
        with zipfile.ZipFile(zip_path, "r") as z:
            files = [
                f for f in z.namelist()
                if table_keyword.upper() in f.upper() and f.endswith(".txt")
            ]
            for file in files:
                # Use a temporary file safely
                with tempfile.NamedTemporaryFile(delete=False, suffix=".txt") as temp_file:
                    temp_file.write(z.read(file))
                    temp_file_path = temp_file.name

                # Read the extracted file with Spark
                df = spark.read.option("delimiter", "$") \
                               .option("header", True) \
                               .option("encoding", "ISO-8859-1") \
                               .csv(temp_file_path)
                
                dfs.append(df)
    
    if dfs:
        # Combine all Spark DataFrames
        combined_df = reduce(DataFrame.unionByName, dfs)
        return combined_df
    else:
        # Return empty DataFrame if no tables found
        return spark.createDataFrame([], schema=None)

# %%
# --- 3️⃣ Read each FAERS table ---
drug_raw = read_faers_tables_spark("DRUG")
reac_raw = read_faers_tables_spark("REAC")
demo_raw = read_faers_tables_spark("DEMO")
outc_raw = read_faers_tables_spark("OUTC")

# %%
from pyspark.sql import functions as F

def clean_drug_table_spark(df):
    drop_cols = [
        'val_vbm','dose_vbm','cum_dose_chr','cum_dose_unit',
        'dechal','rechal','lot_num','exp_dt','nda_num','primaryid'
    ]
    # Drop columns that exist
    df = df.drop(*[c for c in drop_cols if c in df.columns])

    # Lowercase and strip drugname
    df = df.withColumn("drugname", F.lower(F.trim(F.col("drugname"))))

    # Filter by DRUG_LIST_LOWER and role_cod
    df = df.filter(
        (F.col("drugname").isin(DRUG_LIST_LOWER)) &
        (F.col("role_cod").isin("PS", "SS"))
    )

    # Drop duplicates on caseid + drugname
    df = df.dropDuplicates(["caseid", "drugname"])

    # Replace 'Unknown' with null
    for c in df.columns:
        df = df.withColumn(c, F.when(F.col(c) == "Unknown", None).otherwise(F.col(c)))

    # Drop columns with >60% missing values
    total_count = df.count()
    missing_thresh = 0.6 * total_count

    # Calculate missing per column
    missing_counts = df.select([F.count(F.when(F.col(c).isNull(), c)).alias(c) for c in df.columns]).collect()[0].asDict()
    drop_missing_cols = [c for c, cnt in missing_counts.items() if cnt > missing_thresh]
    
    df = df.drop(*drop_missing_cols)

    return df

# --- Usage ---
drug_clean = clean_drug_table_spark(drug_raw)
drug_clean.show(5)
# Out:
# +--------+--------+--------+-------------+--------------------+
# |  caseid|drug_seq|role_cod|     drugname|             prod_ai|
# +--------+--------+--------+-------------+--------------------+
# |10182318|       2|      SS|  pramipexole|PRAMIPEXOLE\PRAMI...|
# |10365773|       5|      SS|oxcarbazepine|       OXCARBAZEPINE|
# |10462505|       1|      PS|carbamazepine|       CARBAMAZEPINE|
# |10497080|       1|      PS|    donepezil|           DONEPEZIL|
# |10609166|       3|      SS|   lacosamide|          LACOSAMIDE|
# +--------+--------+--------+-------------+--------------------+
# only showing top 5 rows

# %%
from pyspark.sql import functions as F

def clean_reac_table_spark(df):
    # Take only relevant columns
    reac_df = df.select("caseid", "pt")
    
    # Aggregate reactions per caseid, sorted and unique
    reac_agg = (
        reac_df.groupBy("caseid")
        .agg(
            F.concat_ws(", ", F.collect_list(F.col("pt"))).alias("pt_list_raw")
        )
    )
    
    # Remove duplicates and sort within each list
    # Convert the comma string to array, remove duplicates, sort, then back to string
    reac_agg = reac_agg.withColumn(
        "pt",
        F.array_join(
            F.sort_array(F.array_distinct(F.split(F.col("pt_list_raw"), ", "))),
            ", "
        )
    ).drop("pt_list_raw")
    
    return reac_agg

# Usage
reac_clean = clean_reac_table_spark(reac_raw)
reac_clean.show(5, truncate=False)
# Out:
# +--------+---------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+
# |caseid  |pt                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                   |
# +--------+---------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+
# |10032297|Arthralgia, Arthritis, Asthenia, Blood cholesterol increased, Blood glucose increased, Blood growth hormone decreased, Blood growth hormone increased, Blood pressure decreased, Blood pressure increased, Bronchitis, Cerebrospinal fluid leakage, Diverticulum, Dizziness, Dizziness postural, Erythema, Eye swelling, Fatigue, Hordeolum, Hypotension, Infected dermal cyst, Injection site reaction, Insulin-like growth factor decreased, Musculoskeletal discomfort, Nasopharyngitis, Nausea, Pain, Pituitary tumour, Pruritus, Pyrexia, Renal failure, Rheumatoid arthritis, Skin disorder, Swelling, Vomiting|
# |10054507|Drug eruption, Drug hypersensitivity                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                 |
# |10142803|Animal bite, Asthma, Blood pressure systolic decreased, Blood pressure systolic increased, Chest discomfort, Cough, Death, Hypersensitivity, Hypopnoea, Influenza like illness, Lethargy, Malaise, Nasal congestion, Nasopharyngitis, Osteoporosis, Pain, Product availability issue, Productive cough, Pyrexia, Respiratory disorder, Respiratory rate increased, Respiratory tract congestion, Rhonchi, Rib fracture, Weight decreased, Wheezing                                                                                                                                                                   |
# |10167865|Klebsiella sepsis                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                    |
# |10182318|Gambling disorder                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                    |
# +--------+---------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+
# only showing top 5 rows

# %%
from pyspark.sql import functions as F

def clean_demo_table_spark(df):
    drop_cols = [
        'rept_cod','to_mfr','caseversion','i_f_code','event_dt',
        'mfr_dt','init_fda_dt','fda_dt','rept_dt','occp_cod',
        'reporter_country','e_sub',
        'primaryid', 'mfr_num', 'mfr_sndr' 
    ]
    
    # Drop columns that exist
    df = df.drop(*[c for c in drop_cols if c in df.columns])

    # Drop columns with >60% missing values (less than 40% non-null)
    total_count = df.count()
    thresh_count = 0.4 * total_count  # at least 40% non-null required
    
    # Calculate non-null counts per column
    non_null_counts = df.select([F.count(F.when(F.col(c).isNotNull(), c)).alias(c) for c in df.columns]).collect()[0].asDict()
    
    drop_missing_cols = [c for c, cnt in non_null_counts.items() if cnt < thresh_count]
    
    df = df.drop(*drop_missing_cols)
    
    return df

# Usage
demo_clean = clean_demo_table_spark(demo_raw)
demo_clean.show(5)
# Out:
# +--------+---+-------+---+------------+
# |  caseid|age|age_cod|sex|occr_country|
# +--------+---+-------+---+------------+
# |10016781| 56|     YR|  F|          CA|
# |10028721| 57|     YR|  F|          CA|
# |10029366| 32|     YR|  M|          AU|
# |10054507| 68|     YR|  F|          US|
# |10057621| 57|     YR|  M|          CA|
# +--------+---+-------+---+------------+
# only showing top 5 rows

# %%
from pyspark.sql import functions as F

def clean_outc_table_spark(df):
    # Take only relevant columns
    outc_df = df.select("caseid", "outc_cod")
    
    # Aggregate outcomes per caseid, collecting all values into a list
    outc_agg = (
        outc_df.groupBy("caseid")
        .agg(F.collect_list(F.col("outc_cod")).alias("outc_list_raw"))
    )
    
    # Remove duplicates within each case, sort, and convert back to string
    outc_agg = outc_agg.withColumn(
        "outc_cod",
        F.array_join(
            F.sort_array(F.array_distinct(F.col("outc_list_raw"))),
            ","
        )
    ).drop("outc_list_raw")
    
    return outc_agg

# Usage
outc_clean = clean_outc_table_spark(outc_raw)
outc_clean.show(5, truncate=False)
# Out:
# +--------+--------+
# |caseid  |outc_cod|
# +--------+--------+
# |10032297|HO,OT   |
# |10142803|DE,OT   |
# |10167865|DE,OT   |
# |10182318|OT      |
# |10201017|HO      |
# +--------+--------+
# only showing top 5 rows

# %%
# --- Step 1: Ensure caseid is string type ---
from pyspark.sql import functions as F

drug_clean = drug_clean.withColumn("caseid", F.col("caseid").cast("string"))
reac_clean = reac_clean.withColumn("caseid", F.col("caseid").cast("string"))
demo_clean = demo_clean.withColumn("caseid", F.col("caseid").cast("string"))
outc_clean = outc_clean.withColumn("caseid", F.col("caseid").cast("string"))

# --- Step 2: Merge drug_clean and reac_clean (inner join) ---
final_df = drug_clean.join(reac_clean, on="caseid", how="inner")

# --- Step 3: Merge with demo_clean (inner join) ---
final_df = final_df.join(demo_clean, on="caseid", how="inner")

# --- Step 4: Merge with outc_clean (left join) ---
final_df = final_df.join(outc_clean, on="caseid", how="left")

# Show first 20 rows, full text without truncation
final_df.show(20, truncate=False)
# Out:
# +--------+--------+--------+-------------+---------------------------------------+---------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+----+-------+----+------------+--------+
# |caseid  |drug_seq|role_cod|drugname     |prod_ai                                |pt                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                             |age |age_cod|sex |occr_country|outc_cod|
# +--------+--------+--------+-------------+---------------------------------------+---------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+----+-------+----+------------+--------+
# |10182318|2       |SS      |pramipexole  |PRAMIPEXOLE\PRAMIPEXOLE DIHYDROCHLORIDE|Gambling disorder                                                                                                                                                                                                                                                                                                                                                                                                                                                                                              |60  |YR     |M   |NULL        |OT      |
# |10923361|1       |PS      |phenytoin    |PHENYTOIN                              |Communication disorder, Condition aggravated, Generalised tonic-clonic seizure, Hyponatraemia, Mental status changes, Metabolic encephalopathy, Social avoidant behaviour, Withdrawal syndrome                                                                                                                                                                                                                                                                                                                 |17  |YR     |M   |US          |HO,OT   |
# |11072044|9       |SS      |ibuprofen    |IBUPROFEN                              |Thrombocytopenia                                                                                                                                                                                                                                                                                                                                                                                                                                                                                               |76  |YR     |F   |US          |HO      |
# |11906898|2       |SS      |pregabalin   |PREGABALIN                             |Brain injury, Myoclonic epilepsy, Pallor                                                                                                                                                                                                                                                                                                                                                                                                                                                                       |NULL|NULL   |M   |CA          |DE,OT   |
# |12186236|1       |PS      |gabapentin   |GABAPENTIN                             |Death                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                          |37  |YR     |F   |US          |DE,OT   |
# |12189885|2       |SS      |gabapentin   |GABAPENTIN                             |Completed suicide                                                                                                                                                                                                                                                                                                                                                                                                                                                                                              |52  |YR     |M   |US          |DE      |
# |12356657|6       |SS      |pregabalin   |PREGABALIN                             |Anaphylactic reaction, Arthralgia, Asthenia, Blood cholesterol increased, Condition aggravated, Contraindicated product administered, Disease recurrence, Drug ineffective, Drug interaction, Drug intolerance, Gastrooesophageal reflux disease, Hepatic enzyme increased, Impaired work ability, Malaise, Mobility decreased, Movement disorder, Muscle spasms, Off label use, Pain, Pain in jaw, Pneumonia, Rash, Rheumatoid arthritis, Swelling, Synovitis, Therapeutic response decreased, Wrist deformity|55  |YR     |F   |CA          |OT      |
# |13077899|8       |SS      |pregabalin   |PREGABALIN                             |Completed suicide, Toxicity to various agents                                                                                                                                                                                                                                                                                                                                                                                                                                                                  |55  |YR     |M   |NULL        |DE,HO,OT|
# |13077899|5       |SS      |gabapentin   |GABAPENTIN                             |Completed suicide, Toxicity to various agents                                                                                                                                                                                                                                                                                                                                                                                                                                                                  |55  |YR     |M   |NULL        |DE,HO,OT|
# |13166376|1       |PS      |gabapentin   |GABAPENTIN                             |Completed suicide                                                                                                                                                                                                                                                                                                                                                                                                                                                                                              |66  |YR     |M   |US          |DE,HO,OT|
# |13225130|1       |PS      |levetiracetam|LEVETIRACETAM                          |Pancytopenia, Pneumonia                                                                                                                                                                                                                                                                                                                                                                                                                                                                                        |77  |YR     |F   |ES          |HO,LT,OT|
# |14008475|3       |SS      |ibuprofen    |IBUPROFEN                              |Allergy test positive, Angioedema, Drug reaction with eosinophilia and systemic symptoms, Exposure during pregnancy, Maternal exposure before pregnancy, Maternal exposure during pregnancy, Off label use, Product use in unapproved indication, Syncope, Urticaria                                                                                                                                                                                                                                           |NULL|NULL   |NULL|PT          |LT,OT   |
# |14160488|1       |PS      |lamotrigine  |LAMOTRIGINE                            |Blood glucose increased, Coma, Drug interaction, Endotracheal intubation, Epilepsy, Seizure                                                                                                                                                                                                                                                                                                                                                                                                                    |66  |YR     |M   |DE          |HO,LT,OT|
# |14182414|1       |PS      |lamotrigine  |LAMOTRIGINE                            |Blood glucose increased, Coma, Drug interaction, Endotracheal intubation, Epilepsy                                                                                                                                                                                                                                                                                                                                                                                                                             |NULL|NULL   |NULL|DE          |HO,LT,OT|
# |14227993|3       |SS      |pregabalin   |PREGABALIN                             |Constipation, Drug interaction, Dyspepsia, Impaired gastric emptying, Renal impairment                                                                                                                                                                                                                                                                                                                                                                                                                         |72  |YR     |F   |NO          |OT      |
# |14277645|1       |PS      |levetiracetam|LEVETIRACETAM                          |Sturge-Weber syndrome                                                                                                                                                                                                                                                                                                                                                                                                                                                                                          |21  |YR     |F   |TR          |CA,HO,OT|
# |14321184|1       |PS      |levetiracetam|LEVETIRACETAM                          |Hallucination                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                  |36  |YR     |F   |ES          |OT      |
# |14360324|20      |SS      |donepezil    |DONEPEZIL                              |Abdominal pain, Abdominal pain upper, Alanine aminotransferase increased, Bradycardia, Diarrhoea, Drug interaction, Dry mouth, Hepatic pain, Hepatitis, Herbal interaction, Hyperhidrosis, Hypokalaemia, Liver disorder, Liver function test increased, Loss of consciousness, Muscle contractions involuntary, Muscle contracture, Muscle spasms, Musculoskeletal chest pain, Nausea, Sedation complication, Somnolence, Syncope                                                                              |85  |YR     |F   |PL          |HO,LT,OT|
# |14647311|3       |PS      |fingolimod   |FINGOLIMOD                             |Bladder pain, Clostridium difficile infection, Cystitis, Diarrhoea, Gastrointestinal infection, Heart rate decreased, Kidney infection, Myocardial infarction, Nausea, Palpitations, Prescribed underdose, Renal disorder, Urinary tract infection, Urinary tract infection bacterial                                                                                                                                                                                                                          |46  |YR     |F   |CA          |OT      |
# |14716733|3       |SS      |valproic acid|VALPROIC ACID                          |Arnold-Chiari malformation, Cardiac aneurysm, Cerebral ventricle dilatation, Congenital oral malformation, Dysmorphism, Foetal anticonvulsant syndrome, Foetal exposure during pregnancy, Ill-defined disorder, Lip disorder, Low set ears, Meningomyelocele, Microcephaly, Paralysis, Spina bifida, Talipes                                                                                                                                                                                                   |NULL|NULL   |F   |DE          |CA,HO,OT|
# +--------+--------+--------+-------------+---------------------------------------+---------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+----+-------+----+------------+--------+
# only showing top 20 rows

# %%
pip install numpy
# Out:
# Requirement already satisfied: numpy in c:\users\user\.pyspark-env\lib\site-packages (2.4.1)
# Note: you may need to restart the kernel to use updated packages.

# %%
from pyspark.sql import functions as F

df_tx = final_df.withColumn("pt_list", F.split(F.col("pt"), ",\\s*"))

df_tx = df_tx.groupBy("caseid").agg(
    F.collect_set("drugname").alias("drug_list"),
    F.first("pt_list").alias("pt_list")
)

df_tx = df_tx.withColumn(
    "items",
    F.array_distinct(F.concat(F.col("drug_list"), F.col("pt_list")))
)

# %%
transactions = (
    df_tx
    .filter(F.col("items").isNotNull())
    .filter(F.size("items") > 1)
    .select("items")
)

# %%
transactions.printSchema()
transactions.filter(F.size("items") <= 1).count()
# Out:
# root
#  |-- items: array (nullable = true)
#  |    |-- element: string (containsNull = false)
# 0

# %%
from pyspark.ml.fpm import FPGrowth

fp = FPGrowth(itemsCol="items", minSupport=0.01, minConfidence=0.1)
model = fp.fit(transactions)

# %%
rules = model.associationRules

rules_ddi = (
    rules
    .filter(F.size("antecedent") == 2)
    .filter(F.size("consequent") == 1)
    .select(
        F.col("antecedent")[0].alias("DrugA"),
        F.col("antecedent")[1].alias("DrugB"),
        F.col("consequent")[0].alias("ADR"),
        F.col("lift").alias("Lift_2Drugs"),
        "support"
    )
)

# %%
rules_ddi = rules_ddi.withColumn(
    "Severity",
    F.when((F.col("Lift_2Drugs") >= 10) & (F.col("support") < 0.002), "Severe (rare)")
     .when(F.col("Lift_2Drugs") >= 2, "Moderate")
     .otherwise("Mild")
)

# %%
pip install streamlit
# Out:
# Requirement already satisfied: streamlit in c:\users\user\.pyspark-env\lib\site-packages (1.53.0)
# Requirement already satisfied: altair!=5.4.0,!=5.4.1,<7,>=4.0 in c:\users\user\.pyspark-env\lib\site-packages (from streamlit) (6.0.0)
# Requirement already satisfied: blinker<2,>=1.5.0 in c:\users\user\.pyspark-env\lib\site-packages (from streamlit) (1.9.0)
# Requirement already satisfied: cachetools<7,>=5.5 in c:\users\user\.pyspark-env\lib\site-packages (from streamlit) (6.2.4)
# Requirement already satisfied: click<9,>=7.0 in c:\users\user\.pyspark-env\lib\site-packages (from streamlit) (8.3.1)
# Requirement already satisfied: numpy<3,>=1.23 in c:\users\user\.pyspark-env\lib\site-packages (from streamlit) (2.4.1)
# Requirement already satisfied: packaging>=20 in c:\users\user\.pyspark-env\lib\site-packages (from streamlit) (25.0)
# Requirement already satisfied: pandas<3,>=1.4.0 in c:\users\user\.pyspark-env\lib\site-packages (from streamlit) (2.3.3)
# Requirement already satisfied: pillow<13,>=7.1.0 in c:\users\user\.pyspark-env\lib\site-packages (from streamlit) (12.1.0)
# Requirement already satisfied: protobuf<7,>=3.20 in c:\users\user\.pyspark-env\lib\site-packages (from streamlit) (6.33.4)
# Requirement already satisfied: pyarrow>=7.0 in c:\users\user\.pyspark-env\lib\site-packages (from streamlit) (23.0.0)
# Requirement already satisfied: requests<3,>=2.27 in c:\users\user\.pyspark-env\lib\site-packages (from streamlit) (2.32.5)
# Requirement already satisfied: tenacity<10,>=8.1.0 in c:\users\user\.pyspark-env\lib\site-packages (from streamlit) (9.1.2)
# Requirement already satisfied: toml<2,>=0.10.1 in c:\users\user\.pyspark-env\lib\site-packages (from streamlit) (0.10.2)
# Requirement already satisfied: typing-extensions<5,>=4.10.0 in c:\users\user\.pyspark-env\lib\site-packages (from streamlit) (4.15.0)
# Requirement already satisfied: watchdog<7,>=2.1.5 in c:\users\user\.pyspark-env\lib\site-packages (from streamlit) (6.0.0)
# Requirement already satisfied: gitpython!=3.1.19,<4,>=3.0.7 in c:\users\user\.pyspark-env\lib\site-packages (from streamlit) (3.1.46)
# Requirement already satisfied: pydeck<1,>=0.8.0b4 in c:\users\user\.pyspark-env\lib\site-packages (from streamlit) (0.9.1)
# Requirement already satisfied: tornado!=6.5.0,<7,>=6.0.3 in c:\users\user\.pyspark-env\lib\site-packages (from streamlit) (6.5.4)
# Requirement already satisfied: jinja2 in c:\users\user\.pyspark-env\lib\site-packages (from altair!=5.4.0,!=5.4.1,<7,>=4.0->streamlit) (3.1.6)
# Requirement already satisfied: jsonschema>=3.0 in c:\users\user\.pyspark-env\lib\site-packages (from altair!=5.4.0,!=5.4.1,<7,>=4.0->streamlit) (4.26.0)
# Requirement already satisfied: narwhals>=1.27.1 in c:\users\user\.pyspark-env\lib\site-packages (from altair!=5.4.0,!=5.4.1,<7,>=4.0->streamlit) (2.15.0)
# Requirement already satisfied: colorama in c:\users\user\.pyspark-env\lib\site-packages (from click<9,>=7.0->streamlit) (0.4.6)
# Requirement already satisfied: gitdb<5,>=4.0.1 in c:\users\user\.pyspark-env\lib\site-packages (from gitpython!=3.1.19,<4,>=3.0.7->streamlit) (4.0.12)
# Requirement already satisfied: smmap<6,>=3.0.1 in c:\users\user\.pyspark-env\lib\site-packages (from gitdb<5,>=4.0.1->gitpython!=3.1.19,<4,>=3.0.7->streamlit) (5.0.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\user\.pyspark-env\lib\site-packages (from pandas<3,>=1.4.0->streamlit) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\user\.pyspark-env\lib\site-packages (from pandas<3,>=1.4.0->streamlit) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\user\.pyspark-env\lib\site-packages (from pandas<3,>=1.4.0->streamlit) (2025.3)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\user\.pyspark-env\lib\site-packages (from requests<3,>=2.27->streamlit) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\user\.pyspark-env\lib\site-packages (from requests<3,>=2.27->streamlit) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\user\.pyspark-env\lib\site-packages (from requests<3,>=2.27->streamlit) (2.6.3)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\user\.pyspark-env\lib\site-packages (from requests<3,>=2.27->streamlit) (2026.1.4)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\user\.pyspark-env\lib\site-packages (from jinja2->altair!=5.4.0,!=5.4.1,<7,>=4.0->streamlit) (3.0.3)
# Requirement already satisfied: attrs>=22.2.0 in c:\users\user\.pyspark-env\lib\site-packages (from jsonschema>=3.0->altair!=5.4.0,!=5.4.1,<7,>=4.0->streamlit) (25.4.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in c:\users\user\.pyspark-env\lib\site-packages (from jsonschema>=3.0->altair!=5.4.0,!=5.4.1,<7,>=4.0->streamlit) (2025.9.1)
# Requirement already satisfied: referencing>=0.28.4 in c:\users\user\.pyspark-env\lib\site-packages (from jsonschema>=3.0->altair!=5.4.0,!=5.4.1,<7,>=4.0->streamlit) (0.37.0)
# Requirement already satisfied: rpds-py>=0.25.0 in c:\users\user\.pyspark-env\lib\site-packages (from jsonschema>=3.0->altair!=5.4.0,!=5.4.1,<7,>=4.0->streamlit) (0.30.0)
# Requirement already satisfied: six>=1.5 in c:\users\user\.pyspark-env\lib\site-packages (from python-dateutil>=2.8.2->pandas<3,>=1.4.0->streamlit) (1.17.0)
# Note: you may need to restart the kernel to use updated packages.
